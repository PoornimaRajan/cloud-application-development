# %%
df= pd.DataFrame({'col':lines})
df.head()

# %%
import pandas as pd
df = pd.read_csv("C:/cloudass2/Final/AppleiPhoneX.csv")

# %%
df
# Out:
#               Reviewer Name              Rating         Riview Date  \
# 0               junior mota  5.0 out of 5 stars  September 11, 2019
# 1                 Nelson J.  5.0 out of 5 stars    February 4, 2019
# 2                T. Almanza  4.0 out of 5 stars       June 27, 2019
# 3    ALLINE LOPES DE LÁZARI  3.0 out of 5 stars    October 24, 2019
# 4             Berner Raquec  4.0 out of 5 stars    February 6, 2019
# 5           Amazon Customer  5.0 out of 5 stars   September 2, 2019
# 6           Amazon Customer  5.0 out of 5 stars         May 2, 2019
# 7                 Mopar gal  2.0 out of 5 stars       June 18, 2019
# 8                Jose ortez  4.0 out of 5 stars       June 26, 2019
# 9              José Antonio  5.0 out of 5 stars   December 24, 2018
# 10             yeonwoo jung  1.0 out of 5 stars       March 4, 2019
# 11                   rachel  3.0 out of 5 stars       June 11, 2019
# 12             Carlos Duque  5.0 out of 5 stars    October 31, 2019
# ...

# %%
df["Review"] = df["Riview Title"] + df["Review Text"]

# %%
df
# Out:
#               Reviewer Name              Rating         Riview Date  \
# 0               junior mota  5.0 out of 5 stars  September 11, 2019
# 1                 Nelson J.  5.0 out of 5 stars    February 4, 2019
# 2                T. Almanza  4.0 out of 5 stars       June 27, 2019
# 3    ALLINE LOPES DE LÁZARI  3.0 out of 5 stars    October 24, 2019
# 4             Berner Raquec  4.0 out of 5 stars    February 6, 2019
# 5           Amazon Customer  5.0 out of 5 stars   September 2, 2019
# 6           Amazon Customer  5.0 out of 5 stars         May 2, 2019
# 7                 Mopar gal  2.0 out of 5 stars       June 18, 2019
# 8                Jose ortez  4.0 out of 5 stars       June 26, 2019
# 9              José Antonio  5.0 out of 5 stars   December 24, 2018
# 10             yeonwoo jung  1.0 out of 5 stars       March 4, 2019
# 11                   rachel  3.0 out of 5 stars       June 11, 2019
# 12             Carlos Duque  5.0 out of 5 stars    October 31, 2019
# ...

# %%
del df["Riview Title"]

# %%
del df["Review Text"]

# %%
del df["Reviewer Name"]

# %%
del df["Rating"]

# %%
del df["Riview Date"]

# %%
df
# Out:
#                                               Review
# 0  PROBLEMAS DE SEÑAL\n            Hola, he tenid...
# 1  Great phone.... Fragile screen!!\n            ...
# 2  Excellent\n            This products is excell...
# 3  The best $600 phone for 2019\n            Good...

# %%
df.to_csv('C:/cloudass2/Final/AppleiPhoneXReview.csv', sep='\t' , header=False, index=False)
